# %%
import numpy as np
import pandas as pd

# %%
ssps = ['SSP126', 'SSP245', 'SSP370', 'SSP585']

fairgp_scores = pd.read_csv('../output/ssps/FaIRGP/cv-scores.csv')
fairgp_scores.index = ssps
fairgp_scores.index.name = 'SSP'

'''
gp_scores = pd.read_csv('../data/experiments/outputs/ssps/plain-GP/cv-scores.csv')
gp_scores.index = ssps
gp_scores.index.name = 'SSP'

fair_scores = pd.read_csv('../data/experiments/outputs/ssps/FaIR/cv-scores.csv')
fair_scores.index = ssps
fair_scores.index.name = 'SSP'
'''
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 ssps = ['SSP126', 'SSP245', 'SSP370', 'SSP585']
# ----> 3 fairgp_scores = pd.read_csv('../output/ssps/FaIRGP/cv-scores.csv')
#       4 fairgp_scores.index = ssps
#       5 fairgp_scores.index.name = 'SSP'
#
# ...

# %%
import os
os.listdir("../")
# Out:
# ['README.md',
#  'fit_spatial_Plain_GP.py',
#  'fit_FaIRGP.py',
#  'fit_fairgp.out',
#  'fit_spatial_FaIRGP.py',
#  'evaluate_FaIRGP.py',
#  'evaluate_Plain_GP.py',
#  'LICENSE',
#  'requirements.txt',
#  'notebooks',
#  'output',
#  'fit_Plain_GP.py',
#  '.ipynb_checkpoints',
#  'src',
#  'evaluate_FaIR.py',
#  'docs',
#  'data',
#  'config',
#  'test.py']

# %%
fairgp_summary = fairgp_scores.aggregate(['mean', 'std'])
gp_summary = gp_scores.aggregate(['mean', 'std'])
fair_summary = fair_scores.aggregate(['mean', 'std'])

fairgp_scores = pd.concat([fairgp_scores, fairgp_summary])
gp_scores = pd.concat([gp_scores, gp_summary])
fair_scores = pd.concat([fair_scores, fair_summary])

# %%
fairgp_scores['Model'] = '2FaIRGP'
gp_scores['Model'] = '1Plain GP'
fair_scores['Model'] = '0FaIR'
metrics_cols = ['Bias', 'RMSE', 'MAE', 'Corr', 'LL', 'Calib95', 'CRPS', 'ICI']
full_scores = pd.concat([fairgp_scores, gp_scores, fair_scores]).sort_index().set_index('Model', append=True)
full_scores.columns = metrics_cols
full_scores = full_scores[['RMSE', 'MAE', 'Bias', 'Corr', 'LL', 'Calib95', 'CRPS']].sort_index().round(2)

# %%
results = full_scores[['RMSE', 'MAE', 'Bias', 'Corr', 'LL', 'Calib95', 'CRPS']].fillna('-')
# results.to_latex('./tables/ssp-experiment-global-scores.tex')
results
# Out:
# /tmp/ipykernel_74450/3373432399.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   results.to_latex('./tables/ssp-experiment-global-scores.tex')
#                   RMSE   MAE  Bias  Corr    LL Calib95  CRPS
#        Model
# SSP126 0FaIR      0.17  0.13  0.06  0.68     -       -     -
#        1Plain GP  0.18  0.14  0.08  0.70  0.23     1.0   0.1
#        2FaIRGP    0.15  0.12  0.02  0.70  0.48    0.97  0.08
# SSP245 0FaIR      0.14  0.12  0.06  0.98     -       -     -
#        1Plain GP  0.09  0.07  0.03  0.98  0.67     1.0  0.06
#        2FaIRGP    0.09  0.08 -0.01  0.98  0.71     1.0  0.06
# SSP370 0FaIR      0.22  0.19  0.10  0.97     -       -     -
#        1Plain GP  0.22  0.17 -0.16  0.98  0.12     1.0  0.12
# ...
